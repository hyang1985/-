# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.tsa.stattools as st
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import AR
from scipy import stats
from pandas import to_datetime

def addZero(symbol):#该函数负责将股票代码前面的0补全
    if(len(symbol)==1):
        return "00000"+symbol
    if(len(symbol)==2):
        return "0000"+symbol
    if(len(symbol)==3):
        return "000"+symbol
    if(len(symbol)==4):
        return "00"+symbol
    if(len(symbol)==5):
        return "0"+symbol
    if(len(symbol)==6):
        return symbol
    
def plotsymbol(symbol,x,y):#画出代码为symbol的股票的图，x可以为日期，y可以为营收，利润等
    plt.plot(Income.loc[Income['TICKER_SYMBOL']==symbol][x],Income.loc[Income['TICKER_SYMBOL']==symbol][y])
    
def isContinuous(t):
    if (t.dtype!='datetime64[ns]'):
        raise "t must be 'datetime64[ns]'"
        return
    if t.size==pd.date_range(t.min(),t.max(),freq='Q').size:
        return True
    else:
        return False

Income=pd.read_excel("C:/FDDC_financial_data/FDDC_financial_data/Financial Data/Income Statement.xls",sheet_name="General Business")

# %%
#将股票代码变为字符串型
Income['TICKER_SYMBOL']=Income['TICKER_SYMBOL'].astype(str)
#股票代码加0
Income['TICKER_SYMBOL']=Income['TICKER_SYMBOL'].apply(addZero)
#将END_DATE转变为日期类型
Income['END_DATE']=pd.to_datetime(Income['END_DATE'],format='%Y-%m-%d')
Income=Income.loc[:,['END_DATE','TICKER_SYMBOL','REVENUE']]
Income=Income.sort_values(by=['END_DATE', 'TICKER_SYMBOL'])

# %%
Income.duplicated().sum()
# Out:
# 91238

# %%
Income[['TICKER_SYMBOL','END_DATE']].duplicated().sum()
# Out:
# 97281

# %%
#观察重复值的样本，可以发现第二次重复的值有了新的值，可能是报告期补充了新的数据，
Income[(Income['TICKER_SYMBOL']=='000002')&(Income['END_DATE']=='2009-03-31')]
# Out:
#        END_DATE TICKER_SYMBOL       REVENUE
# 940  2009-03-31        000002  8.164319e+09
# 1106 2009-03-31        000002  8.164319e+09

# %%
Income=Income.drop_duplicates(['TICKER_SYMBOL','END_DATE'],keep='last')
print ("处理后的数据有%d行，%d列"%(Income.shape[0],Income.shape[1]))
# Out:
# 处理后的数据有110852行，3列

# %%
#观察同一只股票的同一期，是否还有重复值
Income[['TICKER_SYMBOL','END_DATE']].duplicated().sum()
# Out:
# 0

# %%
Income[(Income['TICKER_SYMBOL']=='000002')&(Income['END_DATE']=='2009-03-31')]
# Out:
#        END_DATE TICKER_SYMBOL       REVENUE
# 1106 2009-03-31        000002  8.164319e+09

# %%
#改变为日期类型index
Income.index=Income['END_DATE']
Income=Income.drop('END_DATE',axis=1)
Income.head()
# Out:
#            TICKER_SYMBOL       REVENUE
# END_DATE
# 2006-12-31        002282  2.836519e+08
# 2006-12-31        002283  4.875759e+08
# 2006-12-31        002284  6.513598e+08
# 2006-12-31        002285  3.443315e+08
# 2006-12-31        002286  2.573427e+08

# %%
Revenue_na=[]
#检测营收是否有首期为空的，如果有，将用线性替代
for symbol in Income['TICKER_SYMBOL'].unique():
    if Income.loc[Income['TICKER_SYMBOL']==symbol]['REVENUE'].isnull().sum()>0:
        Revenue_na.append(symbol)
print (Revenue_na)
# Out:
# ['600145', '600149', '600421', '600738', '900957']

# %%
Income.loc[Income['TICKER_SYMBOL']==symbol]['REVENUE']
# Out:
# END_DATE
# 2017-03-31    2.438434e+09
# 2018-03-31    2.751992e+09
# Name: REVENUE, dtype: float64

# %%
#在处理前，包含营收缺失值的股票代码的缺失情况
j=1
for symbol in Revenue_na:
    temp=Income[Income['TICKER_SYMBOL']==symbol]['REVENUE'].copy()
    temp=temp.interpolate()
    plt.subplot(5,1,j)
    plt.plot(Income.loc[Income['TICKER_SYMBOL']==symbol]['REVENUE'])
    j=j+1
    plt.show()
    for idx in temp.index:
        Income.loc[idx,'REVENUE']=temp.loc[idx,]

# %%
#在处理后，包含营收缺失值的股票代码的缺失情况
j=1
for symbol in Revenue_na:
    plt.subplot(5,1,j)
    plt.plot(Income.loc[Income['TICKER_SYMBOL']==symbol]['REVENUE'])
    j=j+1
    plt.show()

# %%
Income.dtypes
# Out:
# TICKER_SYMBOL     object
# REVENUE          float64
# dtype: object

# %%
fig = plt.figure(figsize=(16,8))
#Income.loc['2008':]['REVENUE'].groupby(Income.index).mean()
plt.plot(Income['REVENUE'].groupby(Income.index).mean())

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(Income['REVENUE'].groupby(Income.index).mean(), lags=24,ax=ax1)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_pacf(Income['REVENUE'].groupby(Income.index).mean(), lags=24,ax=ax1)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout()

# %%
symbol_discontinuous=[]
symbol_continuous=[]
for symbol in Income['TICKER_SYMBOL'].unique():
    if (isContinuous(Income[Income['TICKER_SYMBOL']==symbol].index)==False):
        symbol_discontinuous.append(symbol)
        print ("%s的时间序列不连续"%symbol)
    else:
        symbol_continuous.append(symbol)
# Out:
# 002282的时间序列不连续
# 002283的时间序列不连续
# 002284的时间序列不连续
# 002285的时间序列不连续
# 002286的时间序列不连续
# 002287的时间序列不连续
# 002288的时间序列不连续
# 002289的时间序列不连续
# 002290的时间序列不连续
# 002291的时间序列不连续
# 002292的时间序列不连续
# 002293的时间序列不连续
# 002294的时间序列不连续
# 002295的时间序列不连续
# 002296的时间序列不连续
# 002297的时间序列不连续
# 002298的时间序列不连续
# 002299的时间序列不连续
# 002300的时间序列不连续
# 002301的时间序列不连续
# 002302的时间序列不连续
# 002303的时间序列不连续
# 002304的时间序列不连续
# 002305的时间序列不连续
# 002306的时间序列不连续
# 002307的时间序列不连续
# 002308的时间序列不连续
# 002309的时间序列不连续
# 002310的时间序列不连续
# 002311的时间序列不连续
# 002312的时间序列不连续
# 002313的时间序列不连续
# 002314的时间序列不连续
# 002315的时间序列不连续
# 002316的时间序列不连续
# 002317的时间序列不连续
# 002318的时间序列不连续
# 002319的时间序列不连续
# 002320的时间序列不连续
# 002321的时间序列不连续
# 002322的时间序列不连续
# 002323的时间序列不连续
# 002324的时间序列不连续
# 002325的时间序列不连续
# 002326的时间序列不连续
# 002327的时间序列不连续
# 002328的时间序列不连续
# 002329的时间序列不连续
# 002330的时间序列不连续
# 002331的时间序列不连续
# 002332的时间序列不连续
# 002333的时间序列不连续
# 002334的时间序列不连续
# 002335的时间序列不连续
# 002336的时间序列不连续
# 002337的时间序列不连续
# 002338的时间序列不连续
# 002339的时间序列不连续
# 002340的时间序列不连续
# 002341的时间序列不连续
# 002342的时间序列不连续
# 002343的时间序列不连续
# 002344的时间序列不连续
# 002345的时间序列不连续
# 002346的时间序列不连续
# 002347的时间序列不连续
# 002348的时间序列不连续
# 002349的时间序列不连续
# 002350的时间序列不连续
# 002351的时间序列不连续
# 002352的时间序列不连续
# 002353的时间序列不连续
# 002354的时间序列不连续
# 002355的时间序列不连续
# 002356的时间序列不连续
# 002357的时间序列不连续
# 002358的时间序列不连续
# 002359的时间序列不连续
# 002360的时间序列不连续
# 002361的时间序列不连续
# 002363的时间序列不连续
# 002364的时间序列不连续
# 002366的时间序列不连续
# 002367的时间序列不连续
# 002368的时间序列不连续
# 002369的时间序列不连续
# 002370的时间序列不连续
# 002372的时间序列不连续
# 002373的时间序列不连续
# 002374的时间序列不连续
# 002375的时间序列不连续
# 002376的时间序列不连续
# 002377的时间序列不连续
# 002378的时间序列不连续
# 002379的时间序列不连续
# 002380的时间序列不连续
# 002381的时间序列不连续
# 002382的时间序列不连续
# 002383的时间序列不连续
# 002384的时间序列不连续
# 002385的时间序列不连续
# 002386的时间序列不连续
# 002387的时间序列不连续
# 002388的时间序列不连续
# 002389的时间序列不连续
# 002390的时间序列不连续
# 002391的时间序列不连续
# 002392的时间序列不连续
# 002393的时间序列不连续
# 002394的时间序列不连续
# 002395的时间序列不连续
# 002397的时间序列不连续
# 002398的时间序列不连续
# 002399的时间序列不连续
# 002400的时间序列不连续
# 002401的时间序列不连续
# 002402的时间序列不连续
# 002403的时间序列不连续
# 002404的时间序列不连续
# 002405的时间序列不连续
# 002406的时间序列不连续
# 002407的时间序列不连续
# 002408的时间序列不连续
# 002409的时间序列不连续
# 002410的时间序列不连续
# 002411的时间序列不连续
# 002412的时间序列不连续
# 002413的时间序列不连续
# 002414的时间序列不连续
# 002415的时间序列不连续
# 002416的时间序列不连续
# 002421的时间序列不连续
# 002436的时间序列不连续
# 002455的时间序列不连续
# 300001的时间序列不连续
# 300002的时间序列不连续
# 300003的时间序列不连续
# 300004的时间序列不连续
# 300005的时间序列不连续
# 300006的时间序列不连续
# 300007的时间序列不连续
# 300008的时间序列不连续
# 300009的时间序列不连续
# 300010的时间序列不连续
# 300011的时间序列不连续
# 300012的时间序列不连续
# 300013的时间序列不连续
# 300014的时间序列不连续
# 300015的时间序列不连续
# 300017的时间序列不连续
# 300018的时间序列不连续
# 300019的时间序列不连续
# 300020的时间序列不连续
# 300021的时间序列不连续
# 300022的时间序列不连续
# 300023的时间序列不连续
# 300024的时间序列不连续
# 300025的时间序列不连续
# 300026的时间序列不连续
# 300027的时间序列不连续
# 300028的时间序列不连续
# 300029的时间序列不连续
# 300030的时间序列不连续
# 300031的时间序列不连续
# 300032的时间序列不连续
# 300033的时间序列不连续
# 300034的时间序列不连续
# 300035的时间序列不连续
# 300036的时间序列不连续
# 300037的时间序列不连续
# 300038的时间序列不连续
# 300039的时间序列不连续
# 300040的时间序列不连续
# 300041的时间序列不连续
# 300042的时间序列不连续
# 300043的时间序列不连续
# 300044的时间序列不连续
# 300045的时间序列不连续
# 300046的时间序列不连续
# 300047的时间序列不连续
# 300048的时间序列不连续
# 300049的时间序列不连续
# 300050的时间序列不连续
# 300051的时间序列不连续
# 300052的时间序列不连续
# 300053的时间序列不连续
# 300054的时间序列不连续
# 300055的时间序列不连续
# 300056的时间序列不连续
# 300057的时间序列不连续
# 300058的时间序列不连续
# 300059的时间序列不连续
# 300071的时间序列不连续
# 300139的时间序列不连续
# 601018的时间序列不连续
# 601101的时间序列不连续
# 601106的时间序列不连续
# 601117的时间序列不连续
# 601139的时间序列不连续
# 601158的时间序列不连续
# 601179的时间序列不连续
# 601618的时间序列不连续
# 601678的时间序列不连续
# 601801的时间序列不连续
# 601877的时间序列不连续
# 601888的时间序列不连续
# 601989的时间序列不连续
# 002371的时间序列不连续
# 002417的时间序列不连续
# 002418的时间序列不连续
# 002419的时间序列不连续
# 002420的时间序列不连续
# 002422的时间序列不连续
# 002423的时间序列不连续
# 002424的时间序列不连续
# 002425的时间序列不连续
# 002426的时间序列不连续
# 002427的时间序列不连续
# 002428的时间序列不连续
# 002429的时间序列不连续
# 002430的时间序列不连续
# 002431的时间序列不连续
# 002432的时间序列不连续
# 002433的时间序列不连续
# 002434的时间序列不连续
# 002435的时间序列不连续
# 002437的时间序列不连续
# 002438的时间序列不连续
# 002439的时间序列不连续
# 002440的时间序列不连续
# 002441的时间序列不连续
# 002442的时间序列不连续
# 002443的时间序列不连续
# 002444的时间序列不连续
# 002445的时间序列不连续
# 002446的时间序列不连续
# 002447的时间序列不连续
# 002448的时间序列不连续
# 002449的时间序列不连续
# 002450的时间序列不连续
# 002451的时间序列不连续
# 002452的时间序列不连续
# 002453的时间序列不连续
# 002454的时间序列不连续
# 002456的时间序列不连续
# 002457的时间序列不连续
# 002458的时间序列不连续
# 002459的时间序列不连续
# 002460的时间序列不连续
# 002461的时间序列不连续
# 002462的时间序列不连续
# 002463的时间序列不连续
# 002464的时间序列不连续
# 002465的时间序列不连续
# 002466的时间序列不连续
# 002467的时间序列不连续
# 002468的时间序列不连续
# 002469的时间序列不连续
# 002470的时间序列不连续
# 002471的时间序列不连续
# 002472的时间序列不连续
# 002473的时间序列不连续
# 002474的时间序列不连续
# 002475的时间序列不连续
# 002476的时间序列不连续
# 002477的时间序列不连续
# 002478的时间序列不连续
# 002479的时间序列不连续
# 002480的时间序列不连续
# 002481的时间序列不连续
# 002482的时间序列不连续
# 002483的时间序列不连续
# 002484的时间序列不连续
# 002485的时间序列不连续
# 002486的时间序列不连续
# 002487的时间序列不连续
# 002488的时间序列不连续
# 002490的时间序列不连续
# 002491的时间序列不连续
# 002492的时间序列不连续
# 002493的时间序列不连续
# 002494的时间序列不连续
# 002495的时间序列不连续
# 002496的时间序列不连续
# 002497的时间序列不连续
# 002498的时间序列不连续
# 002499的时间序列不连续
# 002501的时间序列不连续
# 002502的时间序列不连续
# 002503的时间序列不连续
# 002504的时间序列不连续
# 002505的时间序列不连续
# 002506的时间序列不连续
# 002507的时间序列不连续
# 002508的时间序列不连续
# 002509的时间序列不连续
# 002510的时间序列不连续
# 002511的时间序列不连续
# 002512的时间序列不连续
# 002513的时间序列不连续
# 002514的时间序列不连续
# 002515的时间序列不连续
# 002516的时间序列不连续
# 002517的时间序列不连续
# 002518的时间序列不连续
# 002519的时间序列不连续
# 002520的时间序列不连续
# 002521的时间序列不连续
# 002522的时间序列不连续
# 002523的时间序列不连续
# 002524的时间序列不连续
# 002525的时间序列不连续
# 002526的时间序列不连续
# 002527的时间序列不连续
# 002528的时间序列不连续
# 002530的时间序列不连续
# 002531的时间序列不连续
# 002532的时间序列不连续
# 002533的时间序列不连续
# 002534的时间序列不连续
# 002535的时间序列不连续
# 002536的时间序列不连续
# 002537的时间序列不连续
# 002538的时间序列不连续
# 002539的时间序列不连续
# 002540的时间序列不连续
# 002541的时间序列不连续
# 002542的时间序列不连续
# 002543的时间序列不连续
# 002544的时间序列不连续
# 002545的时间序列不连续
# 002546的时间序列不连续
# 002547的时间序列不连续
# 002548的时间序列不连续
# 002549的时间序列不连续
# 002550的时间序列不连续
# 002551的时间序列不连续
# 002552的时间序列不连续
# 002553的时间序列不连续
# 002554的时间序列不连续
# 002555的时间序列不连续
# 002556的时间序列不连续
# 002557的时间序列不连续
# 002558的时间序列不连续
# 002559的时间序列不连续
# 002560的时间序列不连续
# 002561的时间序列不连续
# 002563的时间序列不连续
# 002564的时间序列不连续
# 002565的时间序列不连续
# 002566的时间序列不连续
# 002567的时间序列不连续
# 002569的时间序列不连续
# 002570的时间序列不连续
# 002571的时间序列不连续
# 002576的时间序列不连续
# 002581的时间序列不连续
# 002591的时间序列不连续
# 002593的时间序列不连续
# 002595的时间序列不连续
# 002606的时间序列不连续
# 002609的时间序列不连续
# 002613的时间序列不连续
# 002614的时间序列不连续
# 002615的时间序列不连续
# 002622的时间序列不连续
# 002630的时间序列不连续
# 002643的时间序列不连续
# 002644的时间序列不连续
# 002769的时间序列不连续
# 002805的时间序列不连续
# 002889的时间序列不连续
# 300061的时间序列不连续
# 300062的时间序列不连续
# 300063的时间序列不连续
# 300064的时间序列不连续
# 300065的时间序列不连续
# 300066的时间序列不连续
# 300067的时间序列不连续
# 300068的时间序列不连续
# 300069的时间序列不连续
# 300070的时间序列不连续
# 300072的时间序列不连续
# 300073的时间序列不连续
# 300074的时间序列不连续
# 300075的时间序列不连续
# 300076的时间序列不连续
# 300077的时间序列不连续
# 300078的时间序列不连续
# 300079的时间序列不连续
# 300080的时间序列不连续
# 300081的时间序列不连续
# 300082的时间序列不连续
# 300083的时间序列不连续
# 300084的时间序列不连续
# 300085的时间序列不连续
# 300086的时间序列不连续
# 300087的时间序列不连续
# 300088的时间序列不连续
# 300089的时间序列不连续
# 300090的时间序列不连续
# 300091的时间序列不连续
# 300092的时间序列不连续
# 300093的时间序列不连续
# 300094的时间序列不连续
# 300095的时间序列不连续
# 300096的时间序列不连续
# 300097的时间序列不连续
# 300098的时间序列不连续
# 300099的时间序列不连续
# 300100的时间序列不连续
# 300101的时间序列不连续
# 300102的时间序列不连续
# 300103的时间序列不连续
# 300104的时间序列不连续
# 300105的时间序列不连续
# 300106的时间序列不连续
# 300107的时间序列不连续
# 300108的时间序列不连续
# 300109的时间序列不连续
# 300110的时间序列不连续
# 300111的时间序列不连续
# 300112的时间序列不连续
# 300113的时间序列不连续
# 300114的时间序列不连续
# 300115的时间序列不连续
# 300116的时间序列不连续
# 300117的时间序列不连续
# 300118的时间序列不连续
# 300119的时间序列不连续
# 300120的时间序列不连续
# 300121的时间序列不连续
# 300122的时间序列不连续
# 300123的时间序列不连续
# 300124的时间序列不连续
# 300125的时间序列不连续
# 300126的时间序列不连续
# 300127的时间序列不连续
# 300128的时间序列不连续
# 300129的时间序列不连续
# 300130的时间序列不连续
# 300131的时间序列不连续
# 300132的时间序列不连续
# 300133的时间序列不连续
# 300134的时间序列不连续
# 300135的时间序列不连续
# 300136的时间序列不连续
# 300137的时间序列不连续
# 300138的时间序列不连续
# 300140的时间序列不连续
# 300141的时间序列不连续
# 300142的时间序列不连续
# 300143的时间序列不连续
# 300144的时间序列不连续
# 300145的时间序列不连续
# 300146的时间序列不连续
# 300147的时间序列不连续
# 300148的时间序列不连续
# 300149的时间序列不连续
# 300151的时间序列不连续
# 300153的时间序列不连续
# 300154的时间序列不连续
# 300155的时间序列不连续
# 300156的时间序列不连续
# 300157的时间序列不连续
# 300158的时间序列不连续
# 300159的时间序列不连续
# 300160的时间序列不连续
# 300161的时间序列不连续
# 300162的时间序列不连续
# 300163的时间序列不连续
# 300164的时间序列不连续
# 300165的时间序列不连续
# 300166的时间序列不连续
# 300167的时间序列不连续
# 300168的时间序列不连续
# 300169的时间序列不连续
# 300170的时间序列不连续
# 300171的时间序列不连续
# 300172的时间序列不连续
# 300173的时间序列不连续
# 300174的时间序列不连续
# 300175的时间序列不连续
# 300176的时间序列不连续
# 300177的时间序列不连续
# 300178的时间序列不连续
# 300179的时间序列不连续
# 300180的时间序列不连续
# 300181的时间序列不连续
# 300182的时间序列不连续
# 300183的时间序列不连续
# 300184的时间序列不连续
# 300185的时间序列不连续
# 300187的时间序列不连续
# 300188的时间序列不连续
# 300189的时间序列不连续
# 300190的时间序列不连续
# 300191的时间序列不连续
# 300192的时间序列不连续
# 300193的时间序列不连续
# 300194的时间序列不连续
# 300195的时间序列不连续
# 300196的时间序列不连续
# 300197的时间序列不连续
# 300198的时间序列不连续
# 300199的时间序列不连续
# 300203的时间序列不连续
# 300204的时间序列不连续
# 300205的时间序列不连续
# 300211的时间序列不连续
# 300214的时间序列不连续
# 300216的时间序列不连续
# 300220的时间序列不连续
# 300223的时间序列不连续
# 300225的时间序列不连续
# 300229的时间序列不连续
# 300235的时间序列不连续
# 300237的时间序列不连续
# 300238的时间序列不连续
# 300240的时间序列不连续
# 300245的时间序列不连续
# 300247的时间序列不连续
# 300253的时间序列不连续
# 300264的时间序列不连续
# 300272的时间序列不连续
# 300277的时间序列不连续
# 300282的时间序列不连续
# 600939的时间序列不连续
# 600998的时间序列不连续
# 601000的时间序列不连续
# 601010的时间序列不连续
# 601011的时间序列不连续
# 601028的时间序列不连续
# 601058的时间序列不连续
# 601116的时间序列不连续
# 601118的时间序列不连续
# 601126的时间序列不连续
# 601137的时间序列不连续
# 601177的时间序列不连续
# 601199的时间序列不连续
# 601258的时间序列不连续
# 601369的时间序列不连续
# 601518的时间序列不连续
# 601519的时间序列不连续
# 601558的时间序列不连续
# 601616的时间序列不连续
# 601669的时间序列不连续
# 601700的时间序列不连续
# 601717的时间序列不连续
# 601718的时间序列不连续
# 601777的时间序列不连续
# 601799的时间序列不连续
# 601890的时间序列不连续
# 601933的时间序列不连续
# 601985的时间序列不连续
# 601992的时间序列不连续
# 601996的时间序列不连续
# 000627的时间序列不连续
# 000693的时间序列不连续
# 000722的时间序列不连续
# 600094的时间序列不连续
# 601668的时间序列不连续
# 300444的时间序列不连续
# 600050的时间序列不连续
# 002562的时间序列不连续
# 002568的时间序列不连续
# 002572的时间序列不连续
# 002573的时间序列不连续
# 002574的时间序列不连续
# 002575的时间序列不连续
# 002577的时间序列不连续
# 002578的时间序列不连续
# 002579的时间序列不连续
# 002580的时间序列不连续
# 002582的时间序列不连续
# 002583的时间序列不连续
# 002584的时间序列不连续
# 002585的时间序列不连续
# 002586的时间序列不连续
# 002587的时间序列不连续
# 002588的时间序列不连续
# 002589的时间序列不连续
# 002590的时间序列不连续
# 002592的时间序列不连续
# 002594的时间序列不连续
# 002596的时间序列不连续
# 002597的时间序列不连续
# 002598的时间序列不连续
# 002599的时间序列不连续
# 002600的时间序列不连续
# 002601的时间序列不连续
# 002602的时间序列不连续
# 002603的时间序列不连续
# 002604的时间序列不连续
# 002605的时间序列不连续
# 002607的时间序列不连续
# 002608的时间序列不连续
# 002610的时间序列不连续
# 002611的时间序列不连续
# 002612的时间序列不连续
# 002616的时间序列不连续
# 002617的时间序列不连续
# 002618的时间序列不连续
# 002619的时间序列不连续
# 002620的时间序列不连续
# 002621的时间序列不连续
# 002623的时间序列不连续
# 002624的时间序列不连续
# 002625的时间序列不连续
# 002626的时间序列不连续
# 002627的时间序列不连续
# 002628的时间序列不连续
# 002629的时间序列不连续
# 002631的时间序列不连续
# 002632的时间序列不连续
# 002633的时间序列不连续
# 002634的时间序列不连续
# 002635的时间序列不连续
# 002636的时间序列不连续
# 002637的时间序列不连续
# 002638的时间序列不连续
# 002639的时间序列不连续
# 002640的时间序列不连续
# 002641的时间序列不连续
# 002642的时间序列不连续
# 002645的时间序列不连续
# 002646的时间序列不连续
# 002647的时间序列不连续
# 002648的时间序列不连续
# 002649的时间序列不连续
# 002650的时间序列不连续
# 002651的时间序列不连续
# 002652的时间序列不连续
# 002653的时间序列不连续
# 002654的时间序列不连续
# 002655的时间序列不连续
# 002656的时间序列不连续
# 002657的时间序列不连续
# 002658的时间序列不连续
# 002659的时间序列不连续
# 002660的时间序列不连续
# 002661的时间序列不连续
# 002662的时间序列不连续
# 002663的时间序列不连续
# 002664的时间序列不连续
# 002665的时间序列不连续
# 002666的时间序列不连续
# 002667的时间序列不连续
# 002668的时间序列不连续
# 002669的时间序列不连续
# 002670的时间序列不连续
# 002671的时间序列不连续
# 002672的时间序列不连续
# 002674的时间序列不连续
# 002675的时间序列不连续
# 002676的时间序列不连续
# 002677的时间序列不连续
# 002682的时间序列不连续
# 002685的时间序列不连续
# 002688的时间序列不连续
# 002690的时间序列不连续
# 002691的时间序列不连续
# 002696的时间序列不连续
# 002699的时间序列不连续
# 002701的时间序列不连续
# 002702的时间序列不连续
# 002778的时间序列不连续
# 002783的时间序列不连续
# 002799的时间序列不连续
# 002830的时间序列不连续
# 002831的时间序列不连续
# 002911的时间序列不连续
# 300200的时间序列不连续
# 300201的时间序列不连续
# 300202的时间序列不连续
# 300206的时间序列不连续
# 300207的时间序列不连续
# 300208的时间序列不连续
# 300209的时间序列不连续
# 300210的时间序列不连续
# 300212的时间序列不连续
# 300215的时间序列不连续
# 300217的时间序列不连续
# 300218的时间序列不连续
# 300219的时间序列不连续
# 300221的时间序列不连续
# 300222的时间序列不连续
# 300224的时间序列不连续
# 300226的时间序列不连续
# 300227的时间序列不连续
# 300228的时间序列不连续
# 300230的时间序列不连续
# 300231的时间序列不连续
# 300232的时间序列不连续
# 300233的时间序列不连续
# 300234的时间序列不连续
# 300236的时间序列不连续
# 300239的时间序列不连续
# 300241的时间序列不连续
# 300242的时间序列不连续
# 300243的时间序列不连续
# 300244的时间序列不连续
# 300246的时间序列不连续
# 300248的时间序列不连续
# 300249的时间序列不连续
# 300250的时间序列不连续
# 300251的时间序列不连续
# 300252的时间序列不连续
# 300254的时间序列不连续
# 300255的时间序列不连续
# 300256的时间序列不连续
# 300257的时间序列不连续
# 300258的时间序列不连续
# 300259的时间序列不连续
# 300260的时间序列不连续
# 300261的时间序列不连续
# 300262的时间序列不连续
# 300263的时间序列不连续
# 300265的时间序列不连续
# 300266的时间序列不连续
# 300267的时间序列不连续
# 300268的时间序列不连续
# 300269的时间序列不连续
# 300270的时间序列不连续
# 300273的时间序列不连续
# 300274的时间序列不连续
# 300275的时间序列不连续
# 300276的时间序列不连续
# 300278的时间序列不连续
# 300279的时间序列不连续
# 300280的时间序列不连续
# 300281的时间序列不连续
# 300283的时间序列不连续
# 300284的时间序列不连续
# 300285的时间序列不连续
# 300286的时间序列不连续
# 300287的时间序列不连续
# 300288的时间序列不连续
# 300289的时间序列不连续
# 300290的时间序列不连续
# 300291的时间序列不连续
# 300292的时间序列不连续
# 300293的时间序列不连续
# 300294的时间序列不连续
# 300295的时间序列不连续
# 300296的时间序列不连续
# 300297的时间序列不连续
# 300298的时间序列不连续
# 300299的时间序列不连续
# 300300的时间序列不连续
# 300301的时间序列不连续
# 300302的时间序列不连续
# 300303的时间序列不连续
# 300304的时间序列不连续
# 300305的时间序列不连续
# 300306的时间序列不连续
# 300307的时间序列不连续
# 300308的时间序列不连续
# 300309的时间序列不连续
# 300310的时间序列不连续
# 300311的时间序列不连续
# 300312的时间序列不连续
# 300313的时间序列不连续
# 300314的时间序列不连续
# 300315的时间序列不连续
# 300316的时间序列不连续
# 300317的时间序列不连续
# 300319的时间序列不连续
# 300320的时间序列不连续
# 300321的时间序列不连续
# 300324的时间序列不连续
# 300325的时间序列不连续
# 300326的时间序列不连续
# 300327的时间序列不连续
# 300329的时间序列不连续
# 300330的时间序列不连续
# 300331的时间序列不连续
# 300337的时间序列不连续
# 300339的时间序列不连续
# 300340的时间序列不连续
# 300343的时间序列不连续
# 300344的时间序列不连续
# 300345的时间序列不连续
# 300346的时间序列不连续
# 300350的时间序列不连续
# 300477的时间序列不连续
# 300483的时间序列不连续
# 300532的时间序列不连续
# 601012的时间序列不连续
# 601038的时间序列不连续
# 601100的时间序列不连续
# 601113的时间序列不连续
# 601163的时间序列不连续
# 601200的时间序列不连续
# 601208的时间序列不连续
# 601216的时间序列不连续
# 601218的时间序列不连续
# 601222的时间序列不连续
# 601231的时间序列不连续
# 601233的时间序列不连续
# 601311的时间序列不连续
# 601339的时间序列不连续
# 601368的时间序列不连续
# 601388的时间序列不连续
# 601515的时间序列不连续
# 601566的时间序列不连续
# 601567的时间序列不连续
# 601599的时间序列不连续
# 601633的时间序列不连续
# 601636的时间序列不连续
# 601677的时间序列不连续
# 601789的时间序列不连续
# 601798的时间序列不连续
# 601800的时间序列不连续
# 601880的时间序列不连续
# 601886的时间序列不连续
# 601908的时间序列不连续
# 601928的时间序列不连续
# 601929的时间序列不连续
# 601965的时间序列不连续
# 603000的时间序列不连续
# 603001的时间序列不连续
# 603002的时间序列不连续
# 603003的时间序列不连续
# 603123的时间序列不连续
# 603128的时间序列不连续
# 603167的时间序列不连续
# 603197的时间序列不连续
# 603333的时间序列不连续
# 603359的时间序列不连续
# 603599的时间序列不连续
# 603861的时间序列不连续
# 603993的时间序列不连续
# 000333的时间序列不连续
# 002678的时间序列不连续
# 002679的时间序列不连续
# 002680的时间序列不连续
# 002681的时间序列不连续
# 002683的时间序列不连续
# 002684的时间序列不连续
# 002686的时间序列不连续
# 002687的时间序列不连续
# 002689的时间序列不连续
# 002692的时间序列不连续
# 002693的时间序列不连续
# 002694的时间序列不连续
# 002695的时间序列不连续
# 002697的时间序列不连续
# 002698的时间序列不连续
# 002700的时间序列不连续
# 002703的时间序列不连续
# 002710的时间序列不连续
# 002720的时间序列不连续
# 002743的时间序列不连续
# 002746的时间序列不连续
# 002748的时间序列不连续
# 002752的时间序列不连续
# 002756的时间序列不连续
# 002773的时间序列不连续
# 002782的时间序列不连续
# 002792的时间序列不连续
# 002815的时间序列不连续
# 002838的时间序列不连续
# 002843的时间序列不连续
# 002851的时间序列不连续
# 002905的时间序列不连续
# 300322的时间序列不连续
# 300323的时间序列不连续
# 300328的时间序列不连续
# 300332的时间序列不连续
# 300333的时间序列不连续
# 300334的时间序列不连续
# 300335的时间序列不连续
# 300336的时间序列不连续
# 300338的时间序列不连续
# 300341的时间序列不连续
# 300342的时间序列不连续
# 300347的时间序列不连续
# 300348的时间序列不连续
# 300349的时间序列不连续
# 300351的时间序列不连续
# 300352的时间序列不连续
# 300354的时间序列不连续
# 300355的时间序列不连续
# 300356的时间序列不连续
# 300361的时间序列不连续
# 300505的时间序列不连续
# 300507的时间序列不连续
# 300546的时间序列不连续
# 300567的时间序列不连续
# 600903的时间序列不连续
# 600959的时间序列不连续
# 601326的时间序列不连续
# 601608的时间序列不连续
# 601968的时间序列不连续
# 603008的时间序列不连续
# 603023的时间序列不连续
# 603077的时间序列不连续
# 603299的时间序列不连续
# 603366的时间序列不连续
# 603399的时间序列不连续
# 603566的时间序列不连续
# 603766的时间序列不连续
# 603767的时间序列不连续
# 603777的时间序列不连续
# 603989的时间序列不连续
# 002706的时间序列不连续
# 300375的时间序列不连续
# 300445的时间序列不连续
# 300381的时间序列不连续
# 300388的时间序列不连续
# 603328的时间序列不连续
# 002705的时间序列不连续
# 002707的时间序列不连续
# 002708的时间序列不连续
# 002709的时间序列不连续
# 002711的时间序列不连续
# 002712的时间序列不连续
# 002713的时间序列不连续
# 002714的时间序列不连续
# 002715的时间序列不连续
# 002716的时间序列不连续
# 002717的时间序列不连续
# 002718的时间序列不连续
# 002719的时间序列不连续
# 002721的时间序列不连续
# 002722的时间序列不连续
# 002723的时间序列不连续
# 002724的时间序列不连续
# 002725的时间序列不连续
# 002726的时间序列不连续
# 002727的时间序列不连续
# 002728的时间序列不连续
# 300318的时间序列不连续
# 300357的时间序列不连续
# 300358的时间序列不连续
# 300359的时间序列不连续
# 300360的时间序列不连续
# 300362的时间序列不连续
# 300363的时间序列不连续
# 300365的时间序列不连续
# 300366的时间序列不连续
# 300367的时间序列不连续
# 300368的时间序列不连续
# 300369的时间序列不连续
# 300371的时间序列不连续
# 300373的时间序列不连续
# 300376的时间序列不连续
# 300377的时间序列不连续
# 300378的时间序列不连续
# 300379的时间序列不连续
# 300380的时间序列不连续
# 300382的时间序列不连续
# 300383的时间序列不连续
# 300385的时间序列不连续
# 300386的时间序列不连续
# 300387的时间序列不连续
# 300389的时间序列不连续
# 300390的时间序列不连续
# 300391的时间序列不连续
# 300396的时间序列不连续
# 300397的时间序列不连续
# 300399的时间序列不连续
# 300400的时间序列不连续
# 300402的时间序列不连续
# 300403的时间序列不连续
# 300405的时间序列不连续
# 600917的时间序列不连续
# 601016的时间序列不连续
# 601225的时间序列不连续
# 601228的时间序列不连续
# 601579的时间序列不连续
# 601969的时间序列不连续
# 603005的时间序列不连续
# 603006的时间序列不连续
# 603009的时间序列不连续
# 603026的时间序列不连续
# 603088的时间序列不连续
# 603099的时间序列不连续
# 603100的时间序列不连续
# 603111的时间序列不连续
# 603126的时间序列不连续
# 603166的时间序列不连续
# 603168的时间序列不连续
# 603225的时间序列不连续
# 603288的时间序列不连续
# 603308的时间序列不连续
# 603456的时间序列不连续
# 603518的时间序列不连续
# 603555的时间序列不连续
# 603609的时间序列不连续
# 603688的时间序列不连续
# 603699的时间序列不连续
# 603806的时间序列不连续
# 603306的时间序列不连续
# 002673的时间序列不连续
# 603686的时间序列不连续
# 603729的时间序列不连续
# 002729的时间序列不连续
# 002730的时间序列不连续
# 002731的时间序列不连续
# 002732的时间序列不连续
# 002733的时间序列不连续
# 002734的时间序列不连续
# 002735的时间序列不连续
# 002737的时间序列不连续
# 002738的时间序列不连续
# 002739的时间序列不连续
# 002740的时间序列不连续
# 002742的时间序列不连续
# 002745的时间序列不连续
# 002747的时间序列不连续
# 002750的时间序列不连续
# 002787的时间序列不连续
# 300364的时间序列不连续
# 300374的时间序列不连续
# 300384的时间序列不连续
# 300392的时间序列不连续
# 300393的时间序列不连续
# 300395的时间序列不连续
# 300398的时间序列不连续
# 300401的时间序列不连续
# 300406的时间序列不连续
# 300407的时间序列不连续
# 300408的时间序列不连续
# 300409的时间序列不连续
# 300410的时间序列不连续
# 300411的时间序列不连续
# 300412的时间序列不连续
# 300413的时间序列不连续
# 300415的时间序列不连续
# 300416的时间序列不连续
# 300417的时间序列不连续
# 300418的时间序列不连续
# 300419的时间序列不连续
# 300420的时间序列不连续
# 300421的时间序列不连续
# 300424的时间序列不连续
# 300425的时间序列不连续
# 300429的时间序列不连续
# 300435的时间序列不连续
# 300437的时间序列不连续
# 300442的时间序列不连续
# 300491的时间序列不连续
# 300494的时间序列不连续
# 300593的时间序列不连续
# 300629的时间序列不连续
# 600023的时间序列不连续
# 601015的时间序列不连续
# 601021的时间序列不连续
# 601069的时间序列不连续
# 601127的时间序列不连续
# 601226的时间序列不连续
# 601611的时间序列不连续
# 603007的时间序列不连续
# 603010的时间序列不连续
# 603011的时间序列不连续
# 603012的时间序列不连续
# 603015的时间序列不连续
# 603017的时间序列不连续
# 603018的时间序列不连续
# 603019的时间序列不连续
# 603020的时间序列不连续
# 603118的时间序列不连续
# 603169的时间序列不连续
# 603188的时间序列不连续
# 603199的时间序列不连续
# 603222的时间序列不连续
# 603368的时间序列不连续
# 603369的时间序列不连续
# 603519的时间序列不连续
# 603558的时间序列不连续
# 603588的时间序列不连续
# 603600的时间序列不连续
# 603601的时间序列不连续
# 603606的时间序列不连续
# 603611的时间序列不连续
# 603636的时间序列不连续
# 603678的时间序列不连续
# 603698的时间序列不连续
# 603725的时间序列不连续
# 603788的时间序列不连续
# 603808的时间序列不连续
# 603822的时间序列不连续
# 603828的时间序列不连续
# 603869的时间序列不连续
# 603889的时间序列不连续
# 603898的时间序列不连续
# 603899的时间序列不连续
# 603969的时间序列不连续
# 603988的时间序列不连续
# 603997的时间序列不连续
# 603998的时间序列不连续
# 002741的时间序列不连续
# 002749的时间序列不连续
# 002751的时间序列不连续
# 002753的时间序列不连续
# 002755的时间序列不连续
# 002757的时间序列不连续
# 002758的时间序列不连续
# 002759的时间序列不连续
# 002760的时间序列不连续
# 002761的时间序列不连续
# 002762的时间序列不连续
# 002763的时间序列不连续
# 002765的时间序列不连续
# 002766的时间序列不连续
# 002767的时间序列不连续
# 002768的时间序列不连续
# 002770的时间序列不连续
# 002771的时间序列不连续
# 002772的时间序列不连续
# 002775的时间序列不连续
# 002776的时间序列不连续
# 002777的时间序列不连续
# 002779的时间序列不连续
# 002780的时间序列不连续
# 002781的时间序列不连续
# 002785的时间序列不连续
# 002786的时间序列不连续
# 002788的时间序列不连续
# 002789的时间序列不连续
# 002790的时间序列不连续
# 002791的时间序列不连续
# 300394的时间序列不连续
# 300404的时间序列不连续
# 300414的时间序列不连续
# 300422的时间序列不连续
# 300423的时间序列不连续
# 300426的时间序列不连续
# 300427的时间序列不连续
# 300428的时间序列不连续
# 300430的时间序列不连续
# 300431的时间序列不连续
# 300432的时间序列不连续
# 300433的时间序列不连续
# 300434的时间序列不连续
# 300436的时间序列不连续
# 300438的时间序列不连续
# 300439的时间序列不连续
# 300440的时间序列不连续
# 300441的时间序列不连续
# 300443的时间序列不连续
# 300446的时间序列不连续
# 300447的时间序列不连续
# 300448的时间序列不连续
# 300449的时间序列不连续
# 300450的时间序列不连续
# 300451的时间序列不连续
# 300452的时间序列不连续
# 300453的时间序列不连续
# 300455的时间序列不连续
# 300456的时间序列不连续
# 300457的时间序列不连续
# 300458的时间序列不连续
# 300459的时间序列不连续
# 300460的时间序列不连续
# 300461的时间序列不连续
# 300462的时间序列不连续
# 300463的时间序列不连续
# 300464的时间序列不连续
# 300465的时间序列不连续
# 300466的时间序列不连续
# 300467的时间序列不连续
# 300468的时间序列不连续
# 300469的时间序列不连续
# 300470的时间序列不连续
# 300471的时间序列不连续
# 300472的时间序列不连续
# 300473的时间序列不连续
# 300475的时间序列不连续
# 300476的时间序列不连续
# 300478的时间序列不连续
# 300479的时间序列不连续
# 300480的时间序列不连续
# 300481的时间序列不连续
# 300482的时间序列不连续
# 300484的时间序列不连续
# 300485的时间序列不连续
# 300486的时间序列不连续
# 300487的时间序列不连续
# 300488的时间序列不连续
# 300489的时间序列不连续
# 300490的时间序列不连续
# 300492的时间序列不连续
# 300493的时间序列不连续
# 300495的时间序列不连续
# 300496的时间序列不连续
# 300497的时间序列不连续
# 300499的时间序列不连续
# 300500的时间序列不连续
# 300501的时间序列不连续
# 300506的时间序列不连续
# 600977的时间序列不连续
# 601155的时间序列不连续
# 601689的时间序列不连续
# 601900的时间序列不连续
# 603021的时间序列不连续
# 603022的时间序列不连续
# 603025的时间序列不连续
# 603030的时间序列不连续
# 603066的时间序列不连续
# 603085的时间序列不连续
# 603108的时间序列不连续
# 603116的时间序列不连续
# 603117的时间序列不连续
# 603158的时间序列不连续
# 603198的时间序列不连续
# 603223的时间序列不连续
# 603227的时间序列不连续
# 603268的时间序列不连续
# 603300的时间序列不连续
# 603309的时间序列不连续
# 603311的时间序列不连续
# 603315的时间序列不连续
# 603318的时间序列不连续
# 603338的时间序列不连续
# 603355的时间序列不连续
# 603377的时间序列不连续
# 603398的时间序列不连续
# 603508的时间序列不连续
# 603520的时间序列不连续
# 603567的时间序列不连续
# 603568的时间序列不连续
# 603589的时间序列不连续
# 603598的时间序列不连续
# 603608的时间序列不连续
# 603616的时间序列不连续
# 603618的时间序列不连续
# 603669的时间序列不连续
# 603696的时间序列不连续
# 603701的时间序列不连续
# 603703的时间序列不连续
# 603717的时间序列不连续
# 603718的时间序列不连续
# 603778的时间序列不连续
# 603789的时间序列不连续
# 603800的时间序列不连续
# 603818的时间序列不连续
# 603838的时间序列不连续
# 603866的时间序列不连续
# 603883的时间序列不连续
# 603885的时间序列不连续
# 603901的时间序列不连续
# 603918的时间序列不连续
# 603936的时间序列不连续
# 603939的时间序列不连续
# 603959的时间序列不连续
# 603968的时间序列不连续
# 603979的时间序列不连续
# 603996的时间序列不连续
# 603999的时间序列不连续
# 002793的时间序列不连续
# 002795的时间序列不连续
# 002796的时间序列不连续
# 002798的时间序列不连续
# 002800的时间序列不连续
# 002801的时间序列不连续
# 002802的时间序列不连续
# 002803的时间序列不连续
# 002806的时间序列不连续
# 002809的时间序列不连续
# 002810的时间序列不连续
# 002811的时间序列不连续
# 002812的时间序列不连续
# 002813的时间序列不连续
# 002816的时间序列不连续
# 002817的时间序列不连续
# 002818的时间序列不连续
# 002819的时间序列不连续
# 002820的时间序列不连续
# 002821的时间序列不连续
# 002822的时间序列不连续
# 002823的时间序列不连续
# 002824的时间序列不连续
# 002825的时间序列不连续
# 002826的时间序列不连续
# 002827的时间序列不连续
# 002828的时间序列不连续
# 002829的时间序列不连续
# 002832的时间序列不连续
# 002833的时间序列不连续
# 002835的时间序列不连续
# 002836的时间序列不连续
# 002837的时间序列不连续
# 002840的时间序列不连续
# 002841的时间序列不连续
# 002842的时间序列不连续
# 002845的时间序列不连续
# 002846的时间序列不连续
# 002847的时间序列不连续
# 002848的时间序列不连续
# 002857的时间序列不连续
# 300474的时间序列不连续
# 300502的时间序列不连续
# 300503的时间序列不连续
# 300508的时间序列不连续
# 300509的时间序列不连续
# 300510的时间序列不连续
# 300511的时间序列不连续
# 300512的时间序列不连续
# 300513的时间序列不连续
# 300515的时间序列不连续
# 300516的时间序列不连续
# 300517的时间序列不连续
# 300518的时间序列不连续
# 300519的时间序列不连续
# 300520的时间序列不连续
# 300521的时间序列不连续
# 300522的时间序列不连续
# 300523的时间序列不连续
# 300525的时间序列不连续
# 300526的时间序列不连续
# 300527的时间序列不连续
# 300528的时间序列不连续
# 300529的时间序列不连续
# 300530的时间序列不连续
# 300531的时间序列不连续
# 300533的时间序列不连续
# 300534的时间序列不连续
# 300535的时间序列不连续
# 300536的时间序列不连续
# 300537的时间序列不连续
# 300538的时间序列不连续
# 300539的时间序列不连续
# 300540的时间序列不连续
# 300541的时间序列不连续
# 300542的时间序列不连续
# 300543的时间序列不连续
# 300545的时间序列不连续
# 300547的时间序列不连续
# 300548的时间序列不连续
# 300549的时间序列不连续
# 300550的时间序列不连续
# 300551的时间序列不连续
# 300552的时间序列不连续
# 300553的时间序列不连续
# 300555的时间序列不连续
# 300556的时间序列不连续
# 300557的时间序列不连续
# 300558的时间序列不连续
# 300559的时间序列不连续
# 300560的时间序列不连续
# 300561的时间序列不连续
# 300562的时间序列不连续
# 300563的时间序列不连续
# 300565的时间序列不连续
# 300566的时间序列不连续
# 300568的时间序列不连续
# 300569的时间序列不连续
# 300570的时间序列不连续
# 300571的时间序列不连续
# 300572的时间序列不连续
# 300573的时间序列不连续
# 300575的时间序列不连续
# 300576的时间序列不连续
# 300577的时间序列不连续
# 300578的时间序列不连续
# 300579的时间序列不连续
# 300580的时间序列不连续
# 300581的时间序列不连续
# 300582的时间序列不连续
# 300583的时间序列不连续
# 300584的时间序列不连续
# 300585的时间序列不连续
# 300586的时间序列不连续
# 300587的时间序列不连续
# 300588的时间序列不连续
# 300589的时间序列不连续
# 300590的时间序列不连续
# 300591的时间序列不连续
# 300592的时间序列不连续
# 300595的时间序列不连续
# 300596的时间序列不连续
# 300597的时间序列不连续
# 300598的时间序列不连续
# 300599的时间序列不连续
# 300600的时间序列不连续
# 300601的时间序列不连续
# 300602的时间序列不连续
# 300603的时间序列不连续
# 300605的时间序列不连续
# 300606的时间序列不连续
# 300607的时间序列不连续
# 300608的时间序列不连续
# 300609的时间序列不连续
# 300610的时间序列不连续
# 300611的时间序列不连续
# 300612的时间序列不连续
# 300615的时间序列不连续
# 300623的时间序列不连续
# 300631的时间序列不连续
# 300633的时间序列不连续
# 600936的时间序列不连续
# 600996的时间序列不连续
# 601020的时间序列不连续
# 601206的时间序列不连续
# 601212的时间序列不连续
# 601500的时间序列不连续
# 601595的时间序列不连续
# 601811的时间序列不连续
# 601858的时间序列不连续
# 601882的时间序列不连续
# 601966的时间序列不连续
# 603016的时间序列不连续
# 603027的时间序列不连续
# 603028的时间序列不连续
# 603029的时间序列不连续
# 603031的时间序列不连续
# 603032的时间序列不连续
# 603033的时间序列不连续
# 603035的时间序列不连续
# 603036的时间序列不连续
# 603037的时间序列不连续
# 603038的时间序列不连续
# 603039的时间序列不连续
# 603040的时间序列不连续
# 603058的时间序列不连续
# 603060的时间序列不连续
# 603067的时间序列不连续
# 603069的时间序列不连续
# 603089的时间序列不连续
# 603090的时间序列不连续
# 603098的时间序列不连续
# 603101的时间序列不连续
# 603131的时间序列不连续
# 603159的时间序列不连续
# 603160的时间序列不连续
# 603165的时间序列不连续
# 603177的时间序列不连续
# 603178的时间序列不连续
# 603186的时间序列不连续
# 603189的时间序列不连续
# 603203的时间序列不连续
# 603208的时间序列不连续
# 603218的时间序列不连续
# 603228的时间序列不连续
# 603238的时间序列不连续
# 603239的时间序列不连续
# 603258的时间序列不连续
# 603260的时间序列不连续
# 603266的时间序列不连续
# 603298的时间序列不连续
# 603313的时间序列不连续
# 603319的时间序列不连续
# 603322的时间序列不连续
# 603330的时间序列不连续
# 603336的时间序列不连续
# 603337的时间序列不连续
# 603339的时间序列不连续
# 603345的时间序列不连续
# 603358的时间序列不连续
# 603360的时间序列不连续
# 603389的时间序列不连续
# 603393的时间序列不连续
# 603416的时间序列不连续
# 603421的时间序列不连续
# 603429的时间序列不连续
# 603444的时间序列不连续
# 603515的时间序列不连续
# 603517的时间序列不连续
# 603528的时间序列不连续
# 603556的时间序列不连续
# 603559的时间序列不连续
# 603569的时间序列不连续
# 603577的时间序列不连续
# 603579的时间序列不连续
# 603585的时间序列不连续
# 603603的时间序列不连续
# 603615的时间序列不连续
# 603626的时间序列不连续
# 603628的时间序列不连续
# 603633的时间序列不连续
# 603637的时间序列不连续
# 603638的时间序列不连续
# 603639的时间序列不连续
# 603656的时间序列不连续
# 603658的时间序列不连续
# 603660的时间序列不连续
# 603663的时间序列不连续
# 603667的时间序列不连续
# 603668的时间序列不连续
# 603677的时间序列不连续
# 603689的时间序列不连续
# 603690的时间序列不连续
# 603708的时间序列不连续
# 603716的时间序列不连续
# 603726的时间序列不连续
# 603727的时间序列不连续
# 603737的时间序列不连续
# 603738的时间序列不连续
# 603779的时间序列不连续
# 603798的时间序列不连续
# 603816的时间序列不连续
# 603817的时间序列不连续
# 603819的时间序列不连续
# 603823的时间序列不连续
# 603839的时间序列不连续
# 603843的时间序列不连续
# 603858的时间序列不连续
# 603859的时间序列不连续
# 603868的时间序列不连续
# 603877的时间序列不连续
# 603878的时间序列不连续
# 603881的时间序列不连续
# 603886的时间序列不连续
# 603887的时间序列不连续
# 603888的时间序列不连续
# 603900的时间序列不连续
# 603909的时间序列不连续
# 603919的时间序列不连续
# 603928的时间序列不连续
# 603929的时间序列不连续
# 603955的时间序列不连续
# 603958的时间序列不连续
# 603966的时间序列不连续
# 603977的时间序列不连续
# 603986的时间序列不连续
# 603987的时间序列不连续
# 603990的时间序列不连续
# 001965的时间序列不连续
# 002774的时间序列不连续
# 002849的时间序列不连续
# 002850的时间序列不连续
# 002852的时间序列不连续
# 002853的时间序列不连续
# 002855的时间序列不连续
# 002856的时间序列不连续
# 002858的时间序列不连续
# 002859的时间序列不连续
# 002860的时间序列不连续
# 002861的时间序列不连续
# 002862的时间序列不连续
# 002863的时间序列不连续
# 002864的时间序列不连续
# 002865的时间序列不连续
# 002866的时间序列不连续
# 002867的时间序列不连续
# 002868的时间序列不连续
# 002869的时间序列不连续
# 002870的时间序列不连续
# 002871的时间序列不连续
# 002872的时间序列不连续
# 002873的时间序列不连续
# 002875的时间序列不连续
# 002876的时间序列不连续
# 002877的时间序列不连续
# 002878的时间序列不连续
# 002879的时间序列不连续
# 002880的时间序列不连续
# 002881的时间序列不连续
# 002882的时间序列不连续
# 002883的时间序列不连续
# 002884的时间序列不连续
# 002885的时间序列不连续
# 002886的时间序列不连续
# 002887的时间序列不连续
# 002888的时间序列不连续
# 002890的时间序列不连续
# 002891的时间序列不连续
# 002892的时间序列不连续
# 002893的时间序列不连续
# 002895的时间序列不连续
# 002896的时间序列不连续
# 002897的时间序列不连续
# 002898的时间序列不连续
# 002899的时间序列不连续
# 002900的时间序列不连续
# 002901的时间序列不连续
# 002902的时间序列不连续
# 002903的时间序列不连续
# 002906的时间序列不连续
# 002907的时间序列不连续
# 002908的时间序列不连续
# 002909的时间序列不连续
# 002910的时间序列不连续
# 002912的时间序列不连续
# 002913的时间序列不连续
# 002915的时间序列不连续
# 002916的时间序列不连续
# 002917的时间序列不连续
# 002918的时间序列不连续
# 002919的时间序列不连续
# 002920的时间序列不连续
# 002921的时间序列不连续
# 002922的时间序列不连续
# 002923的时间序列不连续
# 002925的时间序列不连续
# 002927的时间序列不连续
# 300504的时间序列不连续
# 300514的时间序列不连续
# 300554的时间序列不连续
# 300604的时间序列不连续
# 300613的时间序列不连续
# 300616的时间序列不连续
# 300617的时间序列不连续
# 300618的时间序列不连续
# 300619的时间序列不连续
# 300620的时间序列不连续
# 300621的时间序列不连续
# 300622的时间序列不连续
# 300624的时间序列不连续
# 300625的时间序列不连续
# 300626的时间序列不连续
# 300627的时间序列不连续
# 300628的时间序列不连续
# 300630的时间序列不连续
# 300632的时间序列不连续
# 300635的时间序列不连续
# 300636的时间序列不连续
# 300637的时间序列不连续
# 300638的时间序列不连续
# 300639的时间序列不连续
# 300640的时间序列不连续
# 300641的时间序列不连续
# 300642的时间序列不连续
# 300643的时间序列不连续
# 300645的时间序列不连续
# 300646的时间序列不连续
# 300647的时间序列不连续
# 300648的时间序列不连续
# 300649的时间序列不连续
# 300650的时间序列不连续
# 300651的时间序列不连续
# 300652的时间序列不连续
# 300653的时间序列不连续
# 300654的时间序列不连续
# 300655的时间序列不连续
# 300656的时间序列不连续
# 300657的时间序列不连续
# 300658的时间序列不连续
# 300659的时间序列不连续
# 300660的时间序列不连续
# 300661的时间序列不连续
# 300662的时间序列不连续
# 300663的时间序列不连续
# 300664的时间序列不连续
# 300665的时间序列不连续
# 300666的时间序列不连续
# 300667的时间序列不连续
# 300668的时间序列不连续
# 300669的时间序列不连续
# 300670的时间序列不连续
# 300671的时间序列不连续
# 300672的时间序列不连续
# 300673的时间序列不连续
# 300675的时间序列不连续
# 300676的时间序列不连续
# 300677的时间序列不连续
# 300678的时间序列不连续
# 300679的时间序列不连续
# 300680的时间序列不连续
# 300681的时间序列不连续
# 300682的时间序列不连续
# 300683的时间序列不连续
# 300684的时间序列不连续
# 300685的时间序列不连续
# 300686的时间序列不连续
# 300687的时间序列不连续
# 300688的时间序列不连续
# 300689的时间序列不连续
# 300690的时间序列不连续
# 300691的时间序列不连续
# 300692的时间序列不连续
# 300693的时间序列不连续
# 300695的时间序列不连续
# 300696的时间序列不连续
# 300697的时间序列不连续
# 300698的时间序列不连续
# 300699的时间序列不连续
# 300700的时间序列不连续
# 300701的时间序列不连续
# 300702的时间序列不连续
# 300703的时间序列不连续
# 300705的时间序列不连续
# 300706的时间序列不连续
# 300707的时间序列不连续
# 300708的时间序列不连续
# 300709的时间序列不连续
# 300710的时间序列不连续
# 300711的时间序列不连续
# 300712的时间序列不连续
# 300713的时间序列不连续
# 300715的时间序列不连续
# 300716的时间序列不连续
# 300717的时间序列不连续
# 300718的时间序列不连续
# 300719的时间序列不连续
# 300720的时间序列不连续
# 300721的时间序列不连续
# 300722的时间序列不连续
# 300723的时间序列不连续
# 300725的时间序列不连续
# 300726的时间序列不连续
# 300727的时间序列不连续
# 300728的时间序列不连续
# 300729的时间序列不连续
# 300730的时间序列不连续
# 300731的时间序列不连续
# 300732的时间序列不连续
# 300733的时间序列不连续
# 300735的时间序列不连续
# 300736的时间序列不连续
# 300737的时间序列不连续
# 300738的时间序列不连续
# 300739的时间序列不连续
# 600025的时间序列不连续
# 600933的时间序列不连续
# 601019的时间序列不连续
# 601086的时间序列不连续
# 601366的时间序列不连续
# 601619的时间序列不连续
# 601828的时间序列不连续
# 601949的时间序列不连续
# 601952的时间序列不连续
# 603041的时间序列不连续
# 603042的时间序列不连续
# 603043的时间序列不连续
# 603045的时间序列不连续
# 603050的时间序列不连续
# 603055的时间序列不连续
# 603056的时间序列不连续
# 603063的时间序列不连续
# 603076的时间序列不连续
# 603078的时间序列不连续
# 603079的时间序列不连续
# 603080的时间序列不连续
# 603081的时间序列不连续
# 603083的时间序列不连续
# 603086的时间序列不连续
# 603096的时间序列不连续
# 603103的时间序列不连续
# 603106的时间序列不连续
# 603110的时间序列不连续
# 603113的时间序列不连续
# 603127的时间序列不连续
# 603129的时间序列不连续
# 603133的时间序列不连续
# 603136的时间序列不连续
# 603138的时间序列不连续
# 603139的时间序列不连续
# 603156的时间序列不连续
# 603157的时间序列不连续
# 603161的时间序列不连续
# 603179的时间序列不连续
# 603180的时间序列不连续
# 603181的时间序列不连续
# 603183的时间序列不连续
# 603196的时间序列不连续
# 603200的时间序列不连续
# 603226的时间序列不连续
# 603229的时间序列不连续
# 603232的时间序列不连续
# 603233的时间序列不连续
# 603269的时间序列不连续
# 603277的时间序列不连续
# 603278的时间序列不连续
# 603283的时间序列不连续
# 603286的时间序列不连续
# 603289的时间序列不连续
# 603302的时间序列不连续
# 603303的时间序列不连续
# 603305的时间序列不连续
# 603316的时间序列不连续
# 603320的时间序列不连续
# 603321的时间序列不连续
# 603326的时间序列不连续
# 603329的时间序列不连续
# 603331的时间序列不连续
# 603335的时间序列不连续
# 603356的时间序列不连续
# 603357的时间序列不连续
# 603363的时间序列不连续
# 603365的时间序列不连续
# 603367的时间序列不连续
# 603378的时间序列不连续
# 603380的时间序列不连续
# 603383的时间序列不连续
# 603385的时间序列不连续
# 603386的时间序列不连续
# 603387的时间序列不连续
# 603388的时间序列不连续
# 603396的时间序列不连续
# 603458的时间序列不连续
# 603466的时间序列不连续
# 603477的时间序列不连续
# 603488的时间序列不连续
# 603496的时间序列不连续
# 603499的时间序列不连续
# 603500的时间序列不连续
# 603501的时间序列不连续
# 603505的时间序列不连续
# 603506的时间序列不连续
# 603507的时间序列不连续
# 603516的时间序列不连续
# 603527的时间序列不连续
# 603533的时间序列不连续
# 603535的时间序列不连续
# 603536的时间序列不连续
# 603538的时间序列不连续
# 603557的时间序列不连续
# 603578的时间序列不连续
# 603580的时间序列不连续
# 603586的时间序列不连续
# 603587的时间序列不连续
# 603595的时间序列不连续
# 603602的时间序列不连续
# 603605的时间序列不连续
# 603607的时间序列不连续
# 603612的时间序列不连续
# 603617的时间序列不连续
# 603619的时间序列不连续
# 603630的时间序列不连续
# 603648的时间序列不连续
# 603655的时间序列不连续
# 603659的时间序列不连续
# 603661的时间序列不连续
# 603665的时间序列不连续
# 603676的时间序列不连续
# 603679的时间序列不连续
# 603680的时间序列不连续
# 603683的时间序列不连续
# 603685的时间序列不连续
# 603707的时间序列不连续
# 603709的时间序列不连续
# 603711的时间序列不连续
# 603712的时间序列不连续
# 603721的时间序列不连续
# 603722的时间序列不连续
# 603728的时间序列不连续
# 603730的时间序列不连续
# 603757的时间序列不连续
# 603758的时间序列不连续
# 603768的时间序列不连续
# 603776的时间序列不连续
# 603787的时间序列不连续
# 603797的时间序列不连续
# 603801的时间序列不连续
# 603803的时间序列不连续
# 603809的时间序列不连续
# 603811的时间序列不连续
# 603813的时间序列不连续
# 603825的时间序列不连续
# 603826的时间序列不连续
# 603829的时间序列不连续
# 603833的时间序列不连续
# 603848的时间序列不连续
# 603855的时间序列不连续
# 603856的时间序列不连续
# 603860的时间序列不连续
# 603871的时间序列不连续
# 603879的时间序列不连续
# 603880的时间序列不连续
# 603882的时间序列不连续
# 603890的时间序列不连续
# 603895的时间序列不连续
# 603896的时间序列不连续
# 603903的时间序列不连续
# 603906的时间序列不连续
# 603908的时间序列不连续
# 603912的时间序列不连续
# 603916的时间序列不连续
# 603917的时间序列不连续
# 603920的时间序列不连续
# 603922的时间序列不连续
# 603926的时间序列不连续
# 603933的时间序列不连续
# 603937的时间序列不连续
# 603938的时间序列不连续
# 603960的时间序列不连续
# 603963的时间序列不连续
# 603970的时间序列不连续
# 603976的时间序列不连续
# 603978的时间序列不连续
# 603980的时间序列不连续
# 603985的时间序列不连续
# 603991的时间序列不连续
# 002928的时间序列不连续
# 002929的时间序列不连续
# 002930的时间序列不连续
# 002931的时间序列不连续
# 300454的时间序列不连续
# 300634的时间序列不连续
# 300644的时间序列不连续
# 300740的时间序列不连续
# 300741的时间序列不连续
# 300742的时间序列不连续
# 300743的时间序列不连续
# 300745的时间序列不连续
# 300746的时间序列不连续
# 300747的时间序列不连续
# 300750的时间序列不连续
# 600929的时间序列不连续
# 601138的时间序列不连续
# 601330的时间序列不连续
# 603013的时间序列不连续
# 603059的时间序列不连续
# 603214的时间序列不连续
# 603259的时间序列不连续
# 603301的时间序列不连续
# 603348的时间序列不连续
# 603486的时间序列不连续
# 603596的时间序列不连续
# 603650的时间序列不连续
# 603666的时间序列不连续
# 603693的时间序列不连续
# 603733的时间序列不连续
# 603773的时间序列不连续
# 603876的时间序列不连续
# 603897的时间序列不连续
# 601360的时间序列不连续

# %%
#时间序列不连续的股票代码有多少
len(symbol_discontinuous)

# %%
len(symbol_continuous)

# %%
dtemp=Income['REVENUE'].groupby(Income.index).mean()
model = AR(dtemp)
results_AR = model.fit()
predict_all_market = results_AR.predict(len(dtemp),len(dtemp))
predict_all_market

# %%
#时间轴连续的个股的预测
predict_each_stock=pd.DataFrame(columns=['TICKER_SYMBOL','REVENUE'])

for symbol in symbol_continuous:
    dtemp=Income.loc[Income['TICKER_SYMBOL']==symbol]['REVENUE']
    model = AR(dtemp)
    results_AR = model.fit()
    results_AR
    predict_value = results_AR.predict(len(dtemp),len(dtemp))
    predict_each_stock=predict_each_stock.append({'REVENUE':predict_value,'TICKER_SYMBOL':symbol},ignore_index=True)
    predict_each_stock

# %%
predict_each_stock

# %%
fig = plt.figure(figsize=(10, 8))
plt.title('个股预测',fontproperties='SimHei')
plt.plot(Income.loc[Income['TICKER_SYMBOL']=='000011']['REVENUE'].index,Income.loc[Income['TICKER_SYMBOL']=='000011']['REVENUE'])
plt.plot(pd.to_datetime('2018-06-30',format='%Y-%m-%d'),predict_each_stock.loc[predict_each_stock['TICKER_SYMBOL']=='000011']['REVENUE'],'o')
#Income['END_DATE']=pd.to_datetime(Income['END_DATE'],format='%Y-%m-%d')
#plt.plot(dtemp,'b-',label='True')
plt.legend(loc='lower right')
